# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df= pd.read_csv('CACI Step Up Dataset 1.csv')
df.head()
# Out:
#    Customer ID  Interested in sustainable range Gender    Age  \
# 0          246                                1      M    75+
# 1          364                                1      F  25-34
# 2          601                                0      M  25-34
# 3          725                                1      M  25-34
# 4          768                                0      M  35-44
#
#    TikTok user, at least weekly  Prefer to eat vegan food  \
# 0                          0.20                      1.70
# 1                         31.40                     19.50
# 2                         31.32                     21.68
# 3                         28.20                     13.40
# 4                         15.45                     22.69
#
#    Occupation: Director / Managerial  Occupation: Office Worker  \
# 0                               0.30                       0.60
# 1                               4.70                      10.80
# ...

# %%
print(df['Age'].nunique())
print(df['Age'].value_counts())
# Out:
# 7
# 29.5    1997
# 49.5    1914
# 39.5    1913
# 59.5    1548
# 21.0    1126
# 69.5     875
# 75.0     627
# Name: Age, dtype: int64

# %%
def convert_age_range_to_average(age_range):
    if '-' in age_range:
        start, end = age_range.split('-')
        return (int(start) + int(end)) / 2
    elif age_range == '75+':
        return 75  # Assuming 75+ represents an average age of 75
    else:
        return None
    
df['Age'] = df['Age'].apply(convert_age_range_to_average)
df
# Out:
#       Customer ID  Interested in sustainable range Gender   Age  \
# 0             246                                1      M  75.0
# 1             364                                1      F  29.5
# 2             601                                0      M  29.5
# 3             725                                1      M  29.5
# 4             768                                0      M  39.5
# ...           ...                              ...    ...   ...
# 9995       999802                                1      M  29.5
# 9996       999846                                0      M  29.5
# 9997       999865                                0      O  75.0
# 9998       999914                                0      F  21.0
# 9999       999977                                0      O  69.5
#
#       TikTok user, at least weekly  Prefer to eat vegan food  \
# 0                             0.20                      1.70
# 1                            31.40                     19.50
# ...

# %%
 df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 52 columns):
#  #   Column                                                                         Non-Null Count  Dtype
# ---  ------                                                                         --------------  -----
#  0   Customer ID                                                                    10000 non-null  int64
#  1   Interested in sustainable range                                                10000 non-null  int64
#  2   Gender                                                                         10000 non-null  object
#  3   Age                                                                            10000 non-null  float64
#  4   TikTok user, at least weekly                                                   10000 non-null  float64
#  5   Prefer to eat vegan food                                                       10000 non-null  float64
# ...

# %%
from sklearn.preprocessing import OneHotEncoder, MinMaxScaler
from sklearn.compose import ColumnTransformer

# %%
ohe = OneHotEncoder(sparse=False, drop='first')

# %%
transformer= ColumnTransformer(transformers=[
                        ('tnf3',OneHotEncoder(sparse_output= False, drop= 'first'),['Gender'])
                        ],remainder= 'passthrough')

# %%
transformer.fit_transform(df).shape
# Out:
# (10000, 52)

# %%
import numpy as np
from sklearn.impute import SimpleImputer

from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline,make_pipeline

# %%
trf1= ColumnTransformer([
    ('ohe_gender', OneHotEncoder(sparse= False, handle_unknown= 'ignore'),[2])
],remainder= 'passthrough')

# %%
pipe= Pipeline([
    ('trf1', trf1),
    ])

# %%
pipe= make_pipeline(trf1)

# %%
pipe

# %%
X=pipe.fit(df)
X

# %%
X= df.iloc[:-1].values
X

# %%
iris
